# %%
# !pip install bs4

# %%
# !pip install requests

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %% [markdown]
# 1) all header tags from "en.wikipedia.org/wiki/Main_Page"

# %%
page = requests.get('https://en.wikipedia.org/wiki/Main_Page')
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Wikipedia, the free encyclopedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"660778e3-bca9-407f-9f5c-ddf2f4f09255","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Main_Page","wgTitle":"Main Page","wgCurRevisionId":1004593520,"wgRevisionId":1004593520,"wgArticleId":15580374,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":[],"wgPageContentLanguage":"en","wgPageContentModel":"wikitext","wgRelevantPageName":"Main_Page","wgRelevantArticleId":15580374,"wgIsProbablyEditable":!1,"wgRel
# ...

# %%
soup = BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Wikipedia, the free encyclopedia
#   </title>
#   <script>
# ...

# %%
ht = soup.find_all('h2',class_= 'mp-h2')

# %%
header_titles = []

for i in ht:
    header_titles.append(i.text)

# %%
header_titles
# Out:
# ["From today's featured article",
#  'Did you know\xa0...',
#  'In the news',
#  'On this day',
#  "Today's featured picture",
#  'Other areas of Wikipedia',
#  "Wikipedia's sister projects",
#  'Wikipedia languages']

# %% [markdown]
# The second header has some unwanted characters in it.

# %% [markdown]
# 2) Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release) and save it in form of a CSV file.

# %%
page2 = requests.get('https://www.imdb.com/chart/top/?ref_=nv_mv_250')
page2
# Out:
# <Response [200]>

# %%
soup2 = BeautifulSoup(page2.content)
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
#   <style>
#    body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#   </style>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    IMDb Top 250 - IMDb
#   </title>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_post_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <script>
# ...

# %%
titles = soup2.find_all('td',class_='titleColumn')

# %%
titles
# Out:
# [<td class="titleColumn">
#        1.
#        <a href="/title/tt0111161/" title="Frank Darabont (dir.), Tim Robbins, Morgan Freeman">The Shawshank Redemption</a>
#  <span class="secondaryInfo">(1994)</span>
#  </td>,
#  <td class="titleColumn">
#        2.
#        <a href="/title/tt0068646/" title="Francis Ford Coppola (dir.), Marlon Brando, Al Pacino">The Godfather</a>
#  <span class="secondaryInfo">(1972)</span>
#  </td>,
#  <td class="titleColumn">
#        3.
#        <a href="/title/tt0071562/" title="Francis Ford Coppola (dir.), Al Pacino, Robert De Niro">The Godfather: Part II</a>
#  <span class="secondaryInfo">(1974)</span>
#  </td>,
#  <td class="titleColumn">
#        4.
#        <a href="/title/tt0468569/" title="Christopher Nolan (dir.), Christian Bale, Heath Ledger">The Dark Knight</a>
#  <span class="secondaryInfo">(2008)</span>
#  </td>,
#  <td class="titleColumn">
#        5.
# ...

# %%
movie_titles = []
num = 1
for i in titles:
    if num <= 100:
        movie_titles.append(i.text.replace('\n',''))
        num+=1
    else:
        break;
    
    
movie_titles
# Out:
# ['      1.      The Shawshank Redemption(1994)',
#  '      2.      The Godfather(1972)',
#  '      3.      The Godfather: Part II(1974)',
#  '      4.      The Dark Knight(2008)',
#  '      5.      12 Angry Men(1957)',
#  "      6.      Schindler's List(1993)",
#  '      7.      The Lord of the Rings: The Return of the King(2003)',
#  '      8.      Pulp Fiction(1994)',
#  '      9.      Il buono, il brutto, il cattivo(1966)',
#  '      10.      The Lord of the Rings: The Fellowship of the Ring(2001)',
#  '      11.      Fight Club(1999)',
#  '      12.      Forrest Gump(1994)',
#  '      13.      Inception(2010)',
#  '      14.      The Lord of the Rings: The Two Towers(2002)',
#  '      15.      Star Wars: Episode V - The Empire Strikes Back(1980)',
#  '      16.      The Matrix(1999)',
#  '      17.      Goodfellas(1990)',
#  "      18.      One Flew Over the Cuckoo's Nest(1975)",
#  '      19.      Shichinin no samurai(1954)',
#  '      20.      Se7en(1995)',
# ...

# %%
len(movie_titles[99])
# Out:
# 41

# %%
new_list = [movie_titles[s].replace(movie_titles[s][-6:], "") for s in range(0,100)]

# %%
new_list
# Out:
# ['      1.      The Shawshank Redemption',
#  '      2.      The Godfather',
#  '      3.      The Godfather: Part II',
#  '      4.      The Dark Knight',
#  '      5.      12 Angry Men',
#  "      6.      Schindler's List",
#  '      7.      The Lord of the Rings: The Return of the King',
#  '      8.      Pulp Fiction',
#  '      9.      Il buono, il brutto, il cattivo',
#  '      10.      The Lord of the Rings: The Fellowship of the Ring',
#  '      11.      Fight Club',
#  '      12.      Forrest Gump',
#  '      13.      Inception',
#  '      14.      The Lord of the Rings: The Two Towers',
#  '      15.      Star Wars: Episode V - The Empire Strikes Back',
#  '      16.      The Matrix',
#  '      17.      Goodfellas',
#  "      18.      One Flew Over the Cuckoo's Nest",
#  '      19.      Shichinin no samurai',
#  '      20.      Se7en',
#  '      21.      La vita è bella',
#  '      22.      Cidade de Deus',
#  '      23.      The Silence of the Lambs',
# ...

# %%
len('      1.      ')
# Out:
# 14

# %%
len('      10.      ')
# Out:
# 15

# %%
len('      100.      ')
# Out:
# 16

# %%
len(new_list)
# Out:
# 100

# %%
names = []
for s in range(0,100):
    if s < 9:
        names.append(new_list[s].replace(new_list[s][:14], ""))
    else:
        if s >= 9 and s < 99:
            names.append(new_list[s].replace(new_list[s][:15], ""))
        else:
            names.append(new_list[s].replace(new_list[s][:16], ""))

# %%
names[0:5]
# Out:
# ['The Shawshank Redemption',
#  'The Godfather',
#  'The Godfather: Part II',
#  'The Dark Knight',
#  '12 Angry Men']

# %%
names[98:]
# Out:
# ['The Kid', "Singin' in the Rain"]

# %%
def target(tag,cl):
            
    ol = soup2.find_all(tag,class_ = cl)
    print(ol)
    return ol

# %%
def replace(ol):
        
        l1 = []
        num = 1
        for i in ol:
            if num <= 100:
                l1.append(i.text.replace('\n',''))
                num+=1
            else:
                break
        return l1

# %%
tag = 'span'
cl = 'secondaryInfo'

# %%
year_data = target(tag,cl)
# Out:
# [<span class="secondaryInfo">(1994)</span>, <span class="secondaryInfo">(1972)</span>, <span class="secondaryInfo">(1974)</span>, <span class="secondaryInfo">(2008)</span>, <span class="secondaryInfo">(1957)</span>, <span class="secondaryInfo">(1993)</span>, <span class="secondaryInfo">(2003)</span>, <span class="secondaryInfo">(1994)</span>, <span class="secondaryInfo">(1966)</span>, <span class="secondaryInfo">(2001)</span>, <span class="secondaryInfo">(1999)</span>, <span class="secondaryInfo">(1994)</span>, <span class="secondaryInfo">(2010)</span>, <span class="secondaryInfo">(2002)</span>, <span class="secondaryInfo">(1980)</span>, <span class="secondaryInfo">(1999)</span>, <span class="secondaryInfo">(1990)</span>, <span class="secondaryInfo">(1975)</span>, <span class="secondaryInfo">(1954)</span>, <span class="secondaryInfo">(1995)</span>, <span class="secondaryInfo">(1997)</span>, <span class="secondaryInfo">(2002)</span>, <span class="secondaryInfo">(1991)</span>, <span cl
# ...

# %%
len(year_data)
# Out:
# 250

# %%
year_data[1]
# Out:
# <span class="secondaryInfo">(1972)</span>

# %%
yd = replace(year_data)

# %%
yd[0:5]
# Out:
# ['(1994)', '(1972)', '(1974)', '(2008)', '(1957)']

# %%
len(yd)
# Out:
# 100

# %%
rating_data = target('td','ratingColumn imdbRating')
# Out:
# [<td class="ratingColumn imdbRating">
# <strong title="9.2 based on 2,384,498 user ratings">9.2</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="9.1 based on 1,652,566 user ratings">9.1</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="9.0 based on 1,149,888 user ratings">9.0</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="9.0 based on 2,347,962 user ratings">9.0</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.9 based on 704,057 user ratings">8.9</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.9 based on 1,232,952 user ratings">8.9</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.9 based on 1,668,051 user ratings">8.9</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.8 based on 1,857,194 user ratings">8.8</strong>
# </td>, <td class="ratingColumn imdbRating">
# ...

# %%
rating_data
# Out:
# [<td class="ratingColumn imdbRating">
#  <strong title="9.2 based on 2,384,498 user ratings">9.2</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="9.1 based on 1,652,566 user ratings">9.1</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 1,149,888 user ratings">9.0</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="9.0 based on 2,347,962 user ratings">9.0</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 704,057 user ratings">8.9</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,232,952 user ratings">8.9</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="8.9 based on 1,668,051 user ratings">8.9</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
#  <strong title="8.8 based on 1,857,194 user ratings">8.8</strong>
#  </td>,
#  <td class="ratingColumn imdbRating">
# ...

# %%
rd = replace(rating_data)

# %%
len(rd)
# Out:
# 100

# %%
rd[0:5]
# Out:
# ['9.2', '9.1', '9.0', '9.0', '8.9']

# %%
df = {}

# %%
import pandas as pd

# %%
df['movie'] = names
df['year'] = yd
df['rating'] = rd

# %%
movie_data = pd.DataFrame(df)

# %%
movie_data.head()
# Out:
#                       movie    year rating
# 0  The Shawshank Redemption  (1994)    9.2
# 1             The Godfather  (1972)    9.1
# 2    The Godfather: Part II  (1974)    9.0
# 3           The Dark Knight  (2008)    9.0
# 4              12 Angry Men  (1957)    8.9

# %%
movie_data.shape
# Out:
# (100, 3)

# %%
movie_data.to_csv('Top 100 movies.csv')

# %%
page3 = requests.get('https://www.imdb.com/india/top-rated-indian-movies/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=2e9dfa9b-3e4d-4d39-acd2-8af11f252a59&pf_rd_r=ZBV7DMJJS4PAHCSBSH6C&pf_rd_s=right-5&pf_rd_t=15506&pf_rd_i=top&ref_=chttp_india_tr_rhs_1')

# %%
page3
# Out:
# <Response [200]>

# %%
soup3=BeautifulSoup(page3.content)

# %%
print(soup3.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="app-id=342792525, app-argument=imdb:///?src=mdot" name="apple-itunes-app"/>
#   <style>
#    body#styleguide-v2 {
#                     background: no-repeat fixed center top #000;
#                 }
#   </style>
#   <style>
#    body#styleguide-v2 #root {
#                 box-shadow: none;
#             }
#   </style>
#   <script type="text/javascript">
#    var IMDbTimer={starttime: new Date().getTime(),pt:'java'};
#   </script>
#   <script>
#    if (typeof uet == 'function') {
#       uet("bb", "LoadTitle", {wb: 1});
#     }
#   </script>
#   <script>
#    (function(t){ (t.events = t.events || {})["csm_head_pre_title"] = new Date().getTime(); })(IMDbTimer);
#   </script>
#   <title>
#    Top Rated Indian Movies - IMDb
#   </title>
#   <script>
# ...

# %% [markdown]
# 3) Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e.Name, IMDB rating, Year of release) and save it in form of a CSV file.

# %%
def targetindia(tag,cl):
            
    ol = soup3.find_all(tag,class_ = cl)
    print(ol)
    return ol

# %%
movie_in = targetindia('td','titleColumn')
movie_in
# Out:
# [<td class="titleColumn">
#       1.
#       <a href="/title/tt0048473/" title="Satyajit Ray (dir.), Kanu Bannerjee, Karuna Bannerjee">Pather Panchali</a>
# <span class="secondaryInfo">(1955)</span>
# </td>, <td class="titleColumn">
#       2.
#       <a href="/title/tt0079221/" title="Hrishikesh Mukherjee (dir.), Amol Palekar, Bindiya Goswami">Gol Maal</a>
# <span class="secondaryInfo">(1979)</span>
# </td>, <td class="titleColumn">
#       3.
#       <a href="/title/tt0093603/" title="Mani Ratnam (dir.), Kamal Haasan, Saranya Ponvannan">Nayakan</a>
# <span class="secondaryInfo">(1987)</span>
# </td>, <td class="titleColumn">
#       4.
#       <a href="/title/tt0367495/" title="Sundar C. (dir.), Kamal Haasan, Madhavan">Anbe Sivam</a>
# <span class="secondaryInfo">(2003)</span>
# </td>, <td class="titleColumn">
#       5.
#       <a href="/title/tt0052572/" title="Satyajit Ray (dir.), Soumitra Chatterjee, Sharmila Tagore">Apur Sansar</a>
# <span class="secondaryInfo">(1959)</span>
# ...

# %%
mo_in = replace(movie_in)

# %%
mo_in[0:5]
# Out:
# ['      1.      Pather Panchali(1955)',
#  '      2.      Gol Maal(1979)',
#  '      3.      Nayakan(1987)',
#  '      4.      Anbe Sivam(2003)',
#  '      5.      Apur Sansar(1959)']

# %%
mo_in_new = [mo_in[s].replace(mo_in[s][-6:], "") for s in range(0,100)]

# %%
mo_in_new[0:5]
# Out:
# ['      1.      Pather Panchali',
#  '      2.      Gol Maal',
#  '      3.      Nayakan',
#  '      4.      Anbe Sivam',
#  '      5.      Apur Sansar']

# %%
len('      1.      ')
# Out:
# 14

# %%
names_in = []
for s in range(0,100):
    if s < 9:
        names_in.append(mo_in_new[s].replace(mo_in_new[s][:14], ""))
    else:
        if s >= 9 and s < 99:
            names_in.append(mo_in_new[s].replace(mo_in_new[s][:15], ""))
        else:
            names_in.append(mo_in_new[s].replace(mo_in_new[s][:16], ""))

# %%
names_in[95:]
# Out:
# ['The Legend of Bhagat Singh', 'Barfi!', 'Pink', 'Bommarillu', 'Bombay']

# %%
year_in = targetindia('span','secondaryInfo')
# Out:
# [<span class="secondaryInfo">(1955)</span>, <span class="secondaryInfo">(1979)</span>, <span class="secondaryInfo">(1987)</span>, <span class="secondaryInfo">(2003)</span>, <span class="secondaryInfo">(1959)</span>, <span class="secondaryInfo">(2018)</span>, <span class="secondaryInfo">(2016)</span>, <span class="secondaryInfo">(2021)</span>, <span class="secondaryInfo">(1989)</span>, <span class="secondaryInfo">(1993)</span>, <span class="secondaryInfo">(2004)</span>, <span class="secondaryInfo">(1992)</span>, <span class="secondaryInfo">(2018)</span>, <span class="secondaryInfo">(2019)</span>, <span class="secondaryInfo">(2009)</span>, <span class="secondaryInfo">(2007)</span>, <span class="secondaryInfo">(2015)</span>, <span class="secondaryInfo">(2016)</span>, <span class="secondaryInfo">(2018)</span>, <span class="secondaryInfo">(1991)</span>, <span class="secondaryInfo">(1956)</span>, <span class="secondaryInfo">(1983)</span>, <span class="secondaryInfo">(1957)</span>, <span cl
# ...

# %%
y_in = replace(year_in)

# %%
y_in[0:5]
# Out:
# ['(1955)', '(1979)', '(1987)', '(2003)', '(1959)']

# %%
rating_in = targetindia('td','ratingColumn imdbRating')
r_in = replace(rating_in)
# Out:
# [<td class="ratingColumn imdbRating">
# <strong title="8.5 based on 24,268 user ratings">8.5</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.5 based on 18,195 user ratings">8.5</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.5 based on 16,862 user ratings">8.5</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.5 based on 17,473 user ratings">8.5</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.5 based on 12,431 user ratings">8.5</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.4 based on 9,682 user ratings">8.4</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.4 based on 5,511 user ratings">8.4</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.4 based on 23,223 user ratings">8.4</strong>
# </td>, <td class="ratingColumn imdbRating">
# <strong title="8.4 based on 6,413 user ratings">8.4</strong>
# ...

# %%
r_in[0:5]
# Out:
# ['8.5', '8.5', '8.5', '8.5', '8.5']

# %%
movies_indian = {}

# %%
movies_indian['Movie'] = names_in
movies_indian['Rating'] = r_in
movies_indian['Year'] = y_in

# %%
m_in = pd.DataFrame(movies_indian)

# %%
m_in.to_csv('Indian Top 100 Movies.csv')

# %%
m_in.head()
# Out:
#              Movie Rating    Year
# 0  Pather Panchali    8.5  (1955)
# 1         Gol Maal    8.5  (1979)
# 2          Nayakan    8.5  (1987)
# 3       Anbe Sivam    8.5  (2003)
# 4      Apur Sansar    8.5  (1959)

# %% [markdown]
# 4) Write a python program to scrap book name, author name, genre and book review of any 5 books from ‘www.bookpage.com’

# %%
page4 = requests.get('https://bookpage.com/reviews?book_genre=fiction&page=1')
page4
# Out:
# <Response [200]>

# %%
soup4 = BeautifulSoup(page4.content)
print(soup4.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://opengraphprotocol.org/schema/">
#  <head>
#   <title>
#    Fiction Book Reviews | BookPage
#   </title>
#   <meta content="Fiction book recommendations of the best new books and more." name="description"/>
#   <meta content="book reviews, books and literature, writing and writers" name="keywords"/>
#   <link href="https://bookpage.com/reviews?book_genre=fiction&amp;page=1" rel="canonical"/>
#   <meta content="BookPage.com" property="og:site_name"/>
#   <meta content="Fiction Book Reviews" property="og:title"/>
#   <meta content="Fiction book recommendations of the best new books and more." property="og:description"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://bookpage.com/reviews?book_genre=fiction&amp;page=1" property="og:url"/>
#   <meta content="//www.bookpage.com/default_image.jpg" property="og:image"/>
#   <meta content="summary" name="twitter:card"/>
# ...

# %%
def books(tag,cl):
            
    ol = soup4.find_all(tag,class_ = cl)
    print(ol)
    return ol

# %%
book_names = books('h4','italic')
# Out:
# [<h4 class="italic">
# <a href="/reviews/26173-joan-silber-secrets-happiness-fiction"> <span style="font-style:normal;">★ </span>Secrets of Happiness</a>
# </h4>, <h4 class="italic">
# <a href="/reviews/26194-stacey-swann-olympus-texas-fiction">Olympus, Texas</a>
# </h4>, <h4 class="italic">
# <a href="/reviews/26195-rivers-solomon-sorrowland-fiction"> <span style="font-style:normal;">★ </span>Sorrowland</a>
# </h4>, <h4 class="italic">
# <a href="/reviews/26191-maggie-shipstead-great-circle-fiction"> <span style="font-style:normal;">★ </span>Great Circle</a>
# </h4>, <h4 class="italic">
# <a href="/reviews/26161-chris-whitaker-we-begin-at-end-audio">We Begin at the End</a>
# </h4>, <h4 class="italic">
# <a href="/reviews/26201-jhumpa-lahiri-whereabouts-fiction"> <span style="font-style:normal;">★ </span>Whereabouts</a>
# </h4>, <h4 class="italic">
# <a href="/reviews/26192-fiona-mozley-hot-stew-fiction">Hot Stew</a>
# </h4>, <h4 class="italic">
# ...

# %%
def text(ol):
        
        l1 = []
        num = 1
        for i in ol:
            if num <= 5:
                l1.append(i.text.replace('\n',''))
                num+=1
            else:
                break
        return l1

# %%
book_title = text(book_names)

# %%
book_title[0:5]
# Out:
# [' ★ Secrets of Happiness',
#  'Olympus, Texas',
#  ' ★ Sorrowland',
#  ' ★ Great Circle',
#  'We Begin at the End']

# %%
author_names = books('p','sans bold')
# Out:
# [<p class="sans bold">
# Joan Silber
# </p>, <p class="sans bold">
# Stacey Swann
# </p>, <p class="sans bold">
# Rivers Solomon
# </p>, <p class="sans bold">
# Maggie Shipstead
# </p>, <p class="sans bold">
# Chris Whitaker, George Newbern
# </p>, <p class="sans bold">
# Jhumpa Lahiri
# </p>, <p class="sans bold">
# Fiona Mozley
# </p>, <p class="sans bold">
# Eleanor Morse
# </p>, <p class="sans bold">
# Julietta Henderson
# </p>, <p class="sans bold">
# Katherine Heiny
# </p>]

# %%
author = text(author_names)

# %%
author
# Out:
# ['Joan Silber',
#  'Stacey Swann',
#  'Rivers Solomon',
#  'Maggie Shipstead',
#  'Chris Whitaker, George Newbern']

# %%
genre_names = books('p','genre-links hidden-phone')
# Out:
# [<p class="genre-links hidden-phone">
# <a href="/search?book_genre=fiction">Fiction</a>
#  /
# <a href="/search?book_genre=family_drama">Family Drama</a>
# </p>, <p class="genre-links hidden-phone">
# <a href="/search?book_genre=fiction">Fiction</a>
#  /
# <a href="/search?book_genre=family_drama">Family Drama</a>
# </p>, <p class="genre-links hidden-phone">
# <a href="/search?book_genre=fiction">Fiction</a>
#  /
# <a href="/search?book_genre=gothic_fiction">Gothic Fiction</a>
# </p>, <p class="genre-links hidden-phone">
# <a href="/search?book_genre=fiction">Fiction</a>
#  /
# <a href="/search?book_genre=historical_fiction">Historical Fiction</a>
# </p>, <p class="genre-links hidden-phone">
# <a href="/search?book_genre=audio">Audio</a>
#  /
# <a href="/search?book_genre=fiction">Fiction</a>
#  /
# <a href="/search?book_genre=crime_fiction">Crime Fiction</a>
# </p>, <p class="genre-links hidden-phone">
# <a href="/search?book_genre=fiction">Fiction</a>
#  /
# ...

# %%
genre = text(genre_names)

# %%
genre
# Out:
# ['Fiction / Family Drama',
#  'Fiction / Family Drama',
#  'Fiction / Gothic Fiction',
#  'Fiction / Historical Fiction',
#  'Audio / Fiction / Crime Fiction']

# %%
book_reviews = books('p','excerpt')
# Out:
# [<p class="excerpt">
# Rarely is a novel of moral ideas so buoyant in spirit or so exquisitely crafted.
# </p>, <p class="excerpt">
# A man’s return to his Texas hometown sets off a chain of events as tragic as any caused by the mythological gods.
# </p>, <p class="excerpt">
# Full of horror and love, <strong>Sorrowland</strong> is so perfectly plotted that readers can’t predict what’s to come any better than its characters can.
# </p>, <p class="excerpt">
# Maggie Shipstead offers a marvelous pastiche of adventure and emotion as she explores what it means (and what it takes) to live an unusual life.
# </p>, <p class="excerpt">
# American actor George Newbern’s clear, unhurried narration proves to be the ideal match for Chris Whitaker’s lyricism.
# </p>, <p class="excerpt">
# Jhumpa Lahiri’s novel is like a contemporary orarium, a collection of private devotions to read for insight and comfort before going to bed.
# </p>, <p class="excerpt">
# ...

# %%
book_reviews[0].text
# Out:
# '\nRarely is a novel of moral ideas so buoyant in spirit or so exquisitely crafted.\n'

# %%
review = text(book_reviews)

# %%
review
# Out:
# ['Rarely is a novel of moral ideas so buoyant in spirit or so exquisitely crafted.',
#  'A man’s return to his Texas hometown sets off a chain of events as tragic as any caused by the mythological gods.',
#  'Full of horror and love, Sorrowland is so perfectly plotted that readers can’t predict what’s to come any better than its characters can.',
#  'Maggie Shipstead offers a marvelous pastiche of adventure and emotion as she explores what it means (and what it takes) to live an unusual life.',
#  'American actor George Newbern’s clear, unhurried narration proves to be the ideal match for Chris Whitaker’s lyricism.']

# %%
bookpage = {}

# %%
bookpage['Title'] = book_title
bookpage['Author'] = author
bookpage['Genre'] = genre
bookpage['Review'] = review

bp = pd.DataFrame(bookpage)

# %%
bp.to_csv('books.csv')

# %% [markdown]
# 5. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’.
#
#     You have to scrape:
#
#     i) Top 10 ODI teams in men’s cricket along with the records for matches, points and rating.
#
#     ii) Top 10 ODI Batsmen in men along with the records of their team and rating.
#
#     iii)Top 10 ODI bowlers along with the records of their team and rating.

# %%
page5i = requests.get('https://www.icc-cricket.com/rankings/mens/team-rankings/odi')
page5i
# Out:
# <Response [200]>

# %%
soup5i = BeautifulSoup(page5i.content)
print(soup5i.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta content="ICC Ranking for ODI teams International Cricket Council" name="twitter:title"/>
#   <meta content="website" property="og:type"/>
#   <meta content="summary_large_image" property="twitter:card"/>
#   <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="description"/>
#   <meta content="@icc" property="twitter:site"/>
#   <meta content="Official International Cricket Council ranking for One Day International (ODI) cricket teams. Discover latest ICC rankings table, predict upcoming matches, see points and ratings for all teams." name="twitter:description"/>
#   <meta content="https://www.icc-cricket.com/resources/ver/i/elements/default-thumbnail.jpg" name="twitter:image"/>
# ...

# %%
def mens_odi(tag,cl):
            
    ol = soup5i.find_all(tag,class_ = cl)
    print(ol)
    return ol

# %%
mens_team = mens_odi('span','u-hide-phablet')
# Out:
# [<span class="u-hide-phablet">New Zealand</span>, <span class="u-hide-phablet">Australia</span>, <span class="u-hide-phablet">India</span>, <span class="u-hide-phablet">England</span>, <span class="u-hide-phablet">South Africa</span>, <span class="u-hide-phablet">Pakistan</span>, <span class="u-hide-phablet">Bangladesh</span>, <span class="u-hide-phablet">West Indies</span>, <span class="u-hide-phablet">Sri Lanka</span>, <span class="u-hide-phablet">Afghanistan</span>, <span class="u-hide-phablet">Netherlands</span>, <span class="u-hide-phablet">Ireland</span>, <span class="u-hide-phablet">Zimbabwe</span>, <span class="u-hide-phablet">Oman</span>, <span class="u-hide-phablet">Scotland</span>, <span class="u-hide-phablet">Nepal</span>, <span class="u-hide-phablet">UAE</span>, <span class="u-hide-phablet">Namibia</span>, <span class="u-hide-phablet">United States</span>, <span class="u-hide-phablet">Papua New Guinea</span>, <span class="icn icn-facebook-circle u-hide-phablet"></span>, 
# ...

# %%
def top10(ol):
        
        l1 = []
        num = 1
        for i in ol:
            if num <= 10:
                l1.append(i.text.replace('\n',''))
                num+=1
            else:
                break
        return l1

# %%
teams_odi = top10(mens_team)

# %%
len(teams_odi)
# Out:
# 10

# %%
matches_mens = mens_odi('td','rankings-block__banner--matches')
# Out:
# [<td class="rankings-block__banner--matches">17</td>]

# %%
matches_points = mens_odi('td','table-body__cell u-center-text')
# Out:
# [<td class="table-body__cell u-center-text">25</td>, <td class="table-body__cell u-center-text">2,945</td>, <td class="table-body__cell u-center-text">29</td>, <td class="table-body__cell u-center-text">3,344</td>, <td class="table-body__cell u-center-text">27</td>, <td class="table-body__cell u-center-text">3,100</td>, <td class="table-body__cell u-center-text">20</td>, <td class="table-body__cell u-center-text">2,137</td>, <td class="table-body__cell u-center-text">24</td>, <td class="table-body__cell u-center-text">2,323</td>, <td class="table-body__cell u-center-text">24</td>, <td class="table-body__cell u-center-text">2,157</td>, <td class="table-body__cell u-center-text">27</td>, <td class="table-body__cell u-center-text">2,222</td>, <td class="table-body__cell u-center-text">21</td>, <td class="table-body__cell u-center-text">1,652</td>, <td class="table-body__cell u-center-text">17</td>, <td class="table-body__cell u-center-text">1,054</td>, <td class="table-body__cell u-cent
# ...

# %%
points_mens = mens_odi('td','rankings-block__banner--points')
# Out:
# [<td class="rankings-block__banner--points">2,054</td>]

# %%
rating_mens = mens_odi('td','rankings-block__banner--rating u-text-right')
# Out:
# [<td class="rankings-block__banner--rating u-text-right">
#                             121
#                             <span class="circle-branding circle-branding--top"></span>
# <span class="circle-branding circle-branding--bottom"></span>
# </td>]

# %%
def last9(l1,ol):
        
        num = 1
        for i in ol:
            if num <= 9:
                l1.append(i.text.replace('\n',''))
                num+=1
            else:
                break
        return l1

# %%
mens_matches = top10(matches_mens)
len(mens_matches)
# Out:
# 1

# %%
matches_points
# Out:
# [<td class="table-body__cell u-center-text">25</td>,
#  <td class="table-body__cell u-center-text">2,945</td>,
#  <td class="table-body__cell u-center-text">29</td>,
#  <td class="table-body__cell u-center-text">3,344</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">3,100</td>,
#  <td class="table-body__cell u-center-text">20</td>,
#  <td class="table-body__cell u-center-text">2,137</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,323</td>,
#  <td class="table-body__cell u-center-text">24</td>,
#  <td class="table-body__cell u-center-text">2,157</td>,
#  <td class="table-body__cell u-center-text">27</td>,
#  <td class="table-body__cell u-center-text">2,222</td>,
#  <td class="table-body__cell u-center-text">21</td>,
#  <td class="table-body__cell u-center-text">1,652</td>,
#  <td class="table-body__cell u-center-text">17</td>,
# ...

# %%
def mixedcolumn(l1,ol):
        
        num = 1
        for i in ol:
            if num <= 18:
                l1.append(i.text.replace('\n',''))
                num+=1
            else:
                break
        return l1

# %%
points_matches = []
mixedcolumn(points_matches,matches_points)

print(points_matches)
# Out:
# ['25', '2,945', '29', '3,344', '27', '3,100', '20', '2,137', '24', '2,323', '24', '2,157', '27', '2,222', '21', '1,652', '17', '1,054']

# %%
matches2 = []
points2 = []

for i in range(0,18):
    if i%2 == 0:
        matches2.append(points_matches[i])
    else:
        points2.append(points_matches[i])

# %%
matches2
# Out:
# ['25', '29', '27', '20', '24', '24', '27', '21', '17']

# %%
points2
# Out:
# ['2,945',
#  '3,344',
#  '3,100',
#  '2,137',
#  '2,323',
#  '2,157',
#  '2,222',
#  '1,652',
#  '1,054']

# %%
for i in matches2:
    mens_matches.append(i)

# %%
len(mens_matches)
# Out:
# 10

# %%
mens_points = top10(points_mens)
len(mens_points)
# Out:
# 1

# %%
for i in points2:
    mens_points.append(i)

# %%
len(mens_points)
# Out:
# 10

# %%
mens_ratings = top10(rating_mens)
len(mens_ratings)
# Out:
# 1

# %%
rating_mens1 = mens_odi('td','table-body__cell u-text-right rating')
# Out:
# [<td class="table-body__cell u-text-right rating">118</td>, <td class="table-body__cell u-text-right rating">115</td>, <td class="table-body__cell u-text-right rating">115</td>, <td class="table-body__cell u-text-right rating">107</td>, <td class="table-body__cell u-text-right rating">97</td>, <td class="table-body__cell u-text-right rating">90</td>, <td class="table-body__cell u-text-right rating">82</td>, <td class="table-body__cell u-text-right rating">79</td>, <td class="table-body__cell u-text-right rating">62</td>, <td class="table-body__cell u-text-right rating">50</td>, <td class="table-body__cell u-text-right rating">45</td>, <td class="table-body__cell u-text-right rating">39</td>, <td class="table-body__cell u-text-right rating">34</td>, <td class="table-body__cell u-text-right rating">30</td>, <td class="table-body__cell u-text-right rating">24</td>, <td class="table-body__cell u-text-right rating">21</td>, <td class="table-body__cell u-text-right rating">16</td>, <td cla
# ...

# %%
mens_ratings1 = last9(mens_ratings,rating_mens1)

# %%
mens_ratings1
# Out:
# ['                            121                            ',
#  '118',
#  '115',
#  '115',
#  '107',
#  '97',
#  '90',
#  '82',
#  '79',
#  '62']

# %%
mens_ratings[0]=mens_ratings1[0].replace(' ','')

# %%
mens_ratings1
# Out:
# ['121', '118', '115', '115', '107', '97', '90', '82', '79', '62']

# %%
mens_top_odi = {'Team':teams_odi, 'Matches': mens_matches, 'Points': mens_points, 'Rating':mens_ratings1}

# %%
mens_top_odi_10 = pd.DataFrame(mens_top_odi)

# %%
mens_top_odi_10
# Out:
#            Team Matches Points Rating
# 0   New Zealand      17  2,054    121
# 1     Australia      25  2,945    118
# 2         India      29  3,344    115
# 3       England      27  3,100    115
# 4  South Africa      20  2,137    107
# 5      Pakistan      24  2,323     97
# 6    Bangladesh      24  2,157     90
# 7   West Indies      27  2,222     82
# 8     Sri Lanka      21  1,652     79
# 9   Afghanistan      17  1,054     62

# %% [markdown]
# 5 (i) is done.

# %%
page5ii = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/batting')
page5ii
# Out:
# <Response [200]>

# %%
soup5ii = BeautifulSoup(page5ii.content)

# %%
def mens_top10(tag,cl):
            
    ol = soup5ii.find_all(tag,class_ = cl)
    print(ol)
    return ol

# %%
player1 = mens_top10('div','rankings-block__banner--name-large')
player1
# Out:
# [<div class="rankings-block__banner--name-large">Babar Azam</div>]
# [<div class="rankings-block__banner--name-large">Babar Azam</div>]

# %%
team1 = mens_top10('div','rankings-block__banner--nationality')
# Out:
# [<div class="rankings-block__banner--nationality">
# <div class="flag-15 PAK"></div>
# <span class="rankings-block__banner--nation"></span>PAK
#                     </div>]

# %%
ratings1 = mens_top10('div','rankings-block__banner--rating')
# Out:
# [<div class="rankings-block__banner--rating">865</div>]

# %%
player2 = mens_top10('td','table-body__cell rankings-table__name name')
# Out:
# [<td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/164">Virat Kohli</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/107">Rohit Sharma</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/226">Ross Taylor</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/167">Aaron Finch</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/506">Jonny Bairstow</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/3801">Fakhar Zaman</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/24">Francois du Plessis</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# ...

# %%
players = []
last9(players,player1)
# Out:
# ['Babar Azam']

# %%
last9(players,player2)
# Out:
# ['Babar Azam',
#  'Virat Kohli',
#  'Rohit Sharma',
#  'Ross Taylor',
#  'Aaron Finch',
#  'Jonny Bairstow',
#  'Fakhar Zaman',
#  'Francois du Plessis',
#  'David Warner',
#  'Shai Hope']

# %%
len(players)
# Out:
# 10

# %%
team2 = mens_top10('span',"table-body__logo-text")
# Out:
# [<span class="table-body__logo-text">IND</span>, <span class="table-body__logo-text">IND</span>, <span class="table-body__logo-text">NZ</span>, <span class="table-body__logo-text">AUS</span>, <span class="table-body__logo-text">ENG</span>, <span class="table-body__logo-text">PAK</span>, <span class="table-body__logo-text">SA</span>, <span class="table-body__logo-text">AUS</span>, <span class="table-body__logo-text">WI</span>, <span class="table-body__logo-text">SA</span>, <span class="table-body__logo-text">NZ</span>, <span class="table-body__logo-text">PAK</span>, <span class="table-body__logo-text">ENG</span>, <span class="table-body__logo-text">AUS</span>, <span class="table-body__logo-text">NZ</span>, <span class="table-body__logo-text">IND</span>, <span class="table-body__logo-text">BAN</span>, <span class="table-body__logo-text">ENG</span>, <span class="table-body__logo-text">AUS</span>, <span class="table-body__logo-text">IRE</span>, <span class="table-body__logo-text">SA</spa
# ...

# %%
teams = []
last9(teams,team1)
last9(teams,team2)

len(teams)

teams
# Out:
# ['PAK                    ',
#  'IND',
#  'IND',
#  'NZ',
#  'AUS',
#  'ENG',
#  'PAK',
#  'SA',
#  'AUS',
#  'WI']

# %%
teams[0] = teams[0].replace(' ','')
teams
# Out:
# ['PAK', 'IND', 'IND', 'NZ', 'AUS', 'ENG', 'PAK', 'SA', 'AUS', 'WI']

# %%
ratings2 = mens_top10('td',"table-body__cell rating")

ratings = []
last9(ratings,ratings1)
last9(ratings,ratings2)

ratings
# Out:
# [<td class="table-body__cell rating">857</td>, <td class="table-body__cell rating">825</td>, <td class="table-body__cell rating">801</td>, <td class="table-body__cell rating">791</td>, <td class="table-body__cell rating">785</td>, <td class="table-body__cell rating">778</td>, <td class="table-body__cell rating">778</td>, <td class="table-body__cell rating">773</td>, <td class="table-body__cell rating">773</td>, <td class="table-body__cell rating">756</td>, <td class="table-body__cell rating">754</td>, <td class="table-body__cell rating">751</td>, <td class="table-body__cell rating">723</td>, <td class="table-body__cell rating">707</td>, <td class="table-body__cell rating">707</td>, <td class="table-body__cell rating">706</td>, <td class="table-body__cell rating">698</td>, <td class="table-body__cell rating">689</td>, <td class="table-body__cell rating">684</td>, <td class="table-body__cell rating">684</td>, <td class="table-body__cell rating">680</td>, <td class="table-body__cell rat
# ...

# %%
players_mens = {'Name':players,'Country':teams,'Rating':ratings}

players_mens_top10 = pd.DataFrame(players_mens)
players_mens_top10
# Out:
#                   Name Country Rating
# 0           Babar Azam     PAK    865
# 1          Virat Kohli     IND    857
# 2         Rohit Sharma     IND    825
# 3          Ross Taylor      NZ    801
# 4          Aaron Finch     AUS    791
# 5       Jonny Bairstow     ENG    785
# 6         Fakhar Zaman     PAK    778
# 7  Francois du Plessis      SA    778
# 8         David Warner     AUS    773
# 9            Shai Hope      WI    773

# %% [markdown]
# 5 (ii) is done

# %%
page5iii = requests.get('https://www.icc-cricket.com/rankings/mens/player-rankings/odi/bowling')
page5iii

soup5iii = BeautifulSoup(page5iii.content)
def mens_bowlers10(tag,cl):
            
    ol = soup5iii.find_all(tag,class_ = cl)
    print(ol)
    return ol

# %%
player1 = mens_bowlers10('div','rankings-block__banner--name-large')
player1

team1 = mens_bowlers10('div','rankings-block__banner--nationality')

ratings1 = mens_bowlers10('div','rankings-block__banner--rating')

player2 = mens_bowlers10('td','table-body__cell rankings-table__name name')

team2 = mens_bowlers10('span',"table-body__logo-text")

ratings2 = mens_bowlers10('td',"table-body__cell rating")


players = []
last9(players,player1)

last9(players,player2)

len(players)

print(players)

teams = []
last9(teams,team1)
last9(teams,team2)

len(teams)

print(teams)

ratings = []
last9(ratings,ratings1)
last9(ratings,ratings2)

print(ratings)
# Out:
# [<div class="rankings-block__banner--name-large">Trent Boult</div>]
# [<div class="rankings-block__banner--nationality">
# <div class="flag-15 NZ"></div>
# <span class="rankings-block__banner--nation"></span>NZ
#                     </div>]
# [<div class="rankings-block__banner--rating">737</div>]
# [<td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/4572">Mujeeb Ur Rahman</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/1505">Matt Henry</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/1124">Jasprit Bumrah</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/1597">Mehedi Hasan</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/mens/player-rankings/1664">Kagiso Rabada</a>
# ...

# %%
teams[0]=teams[0].replace(' ','')

# %%
bowlers_mens = {'Name':players,'Country':teams,'Rating':ratings}

bowlers_mens_top10 = pd.DataFrame(bowlers_mens)
bowlers_mens_top10
# Out:
#                Name Country Rating
# 0       Trent Boult      NZ    737
# 1  Mujeeb Ur Rahman     AFG    708
# 2        Matt Henry      NZ    691
# 3    Jasprit Bumrah     IND    690
# 4      Mehedi Hasan     BAN    668
# 5     Kagiso Rabada      SA    666
# 6      Chris Woakes     ENG    665
# 7    Josh Hazlewood     AUS    660
# 8       Pat Cummins     AUS    646
# 9     Mohammad Amir     PAK    638

# %% [markdown]
# 5(iii) is done

# %% [markdown]
# 6. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’.
#
#     You have to scrape:
#
#     i) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.
#
#     ii) Top 10 women’s ODI players along with the records of their team and rating.
#
#     iii)Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
page6i = requests.get('https://www.icc-cricket.com/rankings/womens/team-rankings/odi')
page6i
# Out:
# <Response [200]>

# %%
soup6i = BeautifulSoup(page6i.content)

# %%
def womens_odi(tag,cl):
            
    ol = soup6i.find_all(tag,class_ = cl)
    print(ol)
    return ol

# %%
womens_team = womens_odi('span','u-hide-phablet')
teams_odi = top10(womens_team)
len(teams_odi)
# Out:
# [<span class="u-hide-phablet">Australia</span>, <span class="u-hide-phablet">South Africa</span>, <span class="u-hide-phablet">England</span>, <span class="u-hide-phablet">India</span>, <span class="u-hide-phablet">New Zealand</span>, <span class="u-hide-phablet">West Indies</span>, <span class="u-hide-phablet">Pakistan</span>, <span class="u-hide-phablet">Bangladesh</span>, <span class="u-hide-phablet">Sri Lanka</span>, <span class="u-hide-phablet">Ireland</span>, <span class="icn icn-facebook-circle u-hide-phablet"></span>, <span class="icn icn-twitter-circle u-hide-phablet"></span>, <span class="icn icn-instagram-circle u-hide-phablet"></span>, <span class="icn icn-youtube-circle u-hide-phablet"></span>, <span class="icn icn-tiktok-circle u-hide-phablet"></span>]
# 10

# %%
matches_womens = womens_odi('td','rankings-block__banner--matches')
matches_points = womens_odi('td','table-body__cell u-center-text')
# Out:
# [<td class="rankings-block__banner--matches">18</td>]
# ...

# %%
points_womens = womens_odi('td','rankings-block__banner--points')
rating_womens = womens_odi('td','rankings-block__banner--rating u-text-right')
# Out:
# [<td class="rankings-block__banner--points">2,955</td>]
# [<td class="rankings-block__banner--rating u-text-right">
#                             164
#                             <span class="circle-branding circle-branding--top"></span>
# <span class="circle-branding circle-branding--bottom"></span>
# </td>]

# %%
womens_matches = top10(matches_womens)
len(womens_matches)
# Out:
# 1

# %%
points_matches = []
mixedcolumn(points_matches,matches_points)

print(points_matches)
# Out:
# ['24', '2,828', '17', '1,993', '20', '2,226', '21', '1,947', '12', '1,025', '15', '1,101', '5', '306', '11', '519', '2', '25']

# %%
matches2 = []
points2 = []

for i in range(0,18):
    if i%2 == 0:
        matches2.append(points_matches[i])
    else:
        points2.append(points_matches[i])

# %%
for i in matches2:
    womens_matches.append(i)

# %%
len(womens_matches)
# Out:
# 10

# %%
womens_points = top10(points_womens)
len(womens_points)

for i in points2:
    womens_points.append(i)
    
len(womens_points)
# Out:
# 10

# %%
womens_ratings = top10(rating_womens)
len(womens_ratings)

rating_womens1 = womens_odi('td','table-body__cell u-text-right rating')

womens_ratings1 = last9(womens_ratings,rating_womens1)
# Out:
# [<td class="table-body__cell u-text-right rating">118</td>, <td class="table-body__cell u-text-right rating">117</td>, <td class="table-body__cell u-text-right rating">111</td>, <td class="table-body__cell u-text-right rating">93</td>, <td class="table-body__cell u-text-right rating">85</td>, <td class="table-body__cell u-text-right rating">73</td>, <td class="table-body__cell u-text-right rating">61</td>, <td class="table-body__cell u-text-right rating">47</td>, <td class="table-body__cell u-text-right rating">13</td>]

# %%
womens_ratings1
# Out:
# ['                            164                            ',
#  '118',
#  '117',
#  '111',
#  '93',
#  '85',
#  '73',
#  '61',
#  '47',
#  '13']

# %%
womens_ratings1[0]=womens_ratings1[0].replace(' ','')

# %%
womens_ratings1
# Out:
# ['164', '118', '117', '111', '93', '85', '73', '61', '47', '13']

# %%
womens_top_odi = {'Team':teams_odi, 'Matches': womens_matches, 'Points': womens_points, 'Rating':womens_ratings1}
womens_top_odi_10 = pd.DataFrame(womens_top_odi)
womens_top_odi_10
# Out:
#            Team Matches Points Rating
# 0     Australia      18  2,955    164
# 1  South Africa      24  2,828    118
# 2       England      17  1,993    117
# 3         India      20  2,226    111
# 4   New Zealand      21  1,947     93
# 5   West Indies      12  1,025     85
# 6      Pakistan      15  1,101     73
# 7    Bangladesh       5    306     61
# 8     Sri Lanka      11    519     47
# 9       Ireland       2     25     13

# %% [markdown]
# 6 (i) is done

# %%
page6ii = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/batting')
page6ii

soup6ii = BeautifulSoup(page6ii.content)
def womens_top10(tag,cl):
            
    ol = soup6ii.find_all(tag,class_ = cl)
    print(ol)
    return ol


player1 = womens_top10('div','rankings-block__banner--name-large')
player1

team1 = womens_top10('div','rankings-block__banner--nationality')

ratings1 = womens_top10('div','rankings-block__banner--rating')

player2 = womens_top10('td','table-body__cell rankings-table__name name')

team2 = womens_top10('span',"table-body__logo-text")

ratings2 = womens_top10('td',"table-body__cell rating")


players = []
last9(players,player1)

last9(players,player2)

len(players)

print(players)

teams = []
last9(teams,team1)
last9(teams,team2)

len(teams)

print(teams)

ratings = []
last9(ratings,ratings1)
last9(ratings,ratings2)

print(ratings)
# Out:
# [<div class="rankings-block__banner--name-large">Tammy Beaumont</div>]
# [<div class="rankings-block__banner--nationality">
# <div class="flag-15 ENG"></div>
# <span class="rankings-block__banner--nation"></span>ENG
#                     </div>]
# [<div class="rankings-block__banner--rating">765</div>]
# [<td class="table-body__cell rankings-table__name name">
# <a href="/rankings/womens/player-rankings/1785">Lizelle Lee</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/womens/player-rankings/466">Alyssa Healy</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/womens/player-rankings/469">Meg Lanning</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/womens/player-rankings/487">Amy Satterthwaite</a>
# ...

# %%
teams[0]=teams[0].replace(' ','')

players_womens = {'Name':players,'Country':teams,'Rating':ratings}

players_womens_top10 = pd.DataFrame(players_womens)
players_womens_top10
# Out:
#                 Name Country Rating
# 0     Tammy Beaumont     ENG    765
# 1        Lizelle Lee      SA    758
# 2       Alyssa Healy     AUS    756
# 3    Stafanie Taylor      WI    746
# 4        Meg Lanning     AUS    723
# 5  Amy Satterthwaite      NZ    715
# 6    Smriti Mandhana     IND    710
# 7        Mithali Raj     IND    709
# 8     Natalie Sciver     ENG    685
# 9    Laura Wolvaardt      SA    683

# %% [markdown]
# 6 (ii) is done

# %%
page6iii = requests.get('https://www.icc-cricket.com/rankings/womens/player-rankings/odi/all-rounder')
page6iii

soup6iii = BeautifulSoup(page6iii.content)
def womens_ar10(tag,cl):
            
    ol = soup6iii.find_all(tag,class_ = cl)
    print(ol)
    return ol


player1 = womens_ar10('div','rankings-block__banner--name-large')
player1

team1 = womens_ar10('div','rankings-block__banner--nationality')

ratings1 = womens_ar10('div','rankings-block__banner--rating')

player2 = womens_ar10('td','table-body__cell rankings-table__name name')

team2 = womens_ar10('span',"table-body__logo-text")

ratings2 = womens_ar10('td',"table-body__cell rating")


players = []
last9(players,player1)

last9(players,player2)

len(players)

print(players)

teams = []
last9(teams,team1)
last9(teams,team2)

len(teams)

print(teams)

ratings = []
last9(ratings,ratings1)
last9(ratings,ratings2)

print(ratings)
# Out:
# [<div class="rankings-block__banner--name-large">Marizanne Kapp</div>]
# [<div class="rankings-block__banner--nationality">
# <div class="flag-15 SA"></div>
# <span class="rankings-block__banner--nation"></span>SA
#                     </div>]
# [<div class="rankings-block__banner--rating">418</div>]
# [<td class="table-body__cell rankings-table__name name">
# <a href="/rankings/womens/player-rankings/471">Ellyse Perry</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/womens/player-rankings/573">Stafanie Taylor</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/womens/player-rankings/1800">Natalie Sciver</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/womens/player-rankings/3192">Deepti Sharma</a>
# </td>, <td class="table-body__cell rankings-table__name name">
# <a href="/rankings/womens/player-rankings/468">Jess Jonassen</a>
# ...

# %%
teams[0]=teams[0].replace(' ','')

ar_womens = {'Name':players,'Country':teams,'Rating':ratings}

ar_womens_top10 = pd.DataFrame(ar_womens)
ar_womens_top10
# Out:
#                Name Country Rating
# 0    Marizanne Kapp      SA    418
# 1      Ellyse Perry     AUS    418
# 2   Stafanie Taylor      WI    410
# 3    Natalie Sciver     ENG    349
# 4     Deepti Sharma     IND    343
# 5     Jess Jonassen     AUS    307
# 6  Ashleigh Gardner     AUS    252
# 7  Dane van Niekerk      SA    243
# 8     Sophie Devine      NZ    242
# 9       Amelia Kerr      NZ    236

# %% [markdown]
# 6 (iii) is done.

# %% [markdown]
# 7. Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in.
#
#     The scraped data should include Product Name, Price, Image URL and Average Rating.

# %% [markdown]
# There are 20 web pages for listing phones under 20000 inr

# %%
def get_read_content(link):
    page7 = requests.get(link)
    soup7 = BeautifulSoup(page7.content)
    return soup7

# %%
def get_info(var,tag,cl):
    ol = var.find_all(tag,class_= cl)
    return ol

# %%
def read_text(var,ol):
    num = 1
    for i in ol:
        if num <= len(ol):
            var.append(i.text.replace('\n',''))
            num+=1
        else:
            break
    return var

# %%
name_tag = 'span'
name_class = 'a-size-base-plus a-color-base a-text-normal'

price_tag = 'span' 
price_class = "a-price-whole"

image_url_tag = 'img'
image_url_class = 's-image'

rating_tag = 'span'
rating_class = 'a-icon-alt'

tag = [name_tag,price_tag,image_url_tag,rating_tag]
classes = [name_class,price_class,image_url_class,rating_class]

# %%
def get_read_content1(link,tag,cl):
    page7 = requests.get(link)
    soup7 = BeautifulSoup(page7.content)
    
    ol = soup7.find_all(tag,class_= cl)
    return ol

# %%
page7a = requests.get('https://www.amazon.in/s?k=10000&i=electronics&rh=n%3A976419031%2Cn%3A1389401031%2Cn%3A1389432031%2Cn%3A1805560031&dc&qid=1620317201&rnid=976419031&ref=sr_nr_n_2')
page7a
# Out:
# <Response [200]>

# %%
page7a.content
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41+dLWMMeXL.css,31qGOnSAToL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.css,11bGSgD5pDL.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,21N4kUH7pxL.css,01oDR3IULNL.css,31q1y1irc5L.css,21j0IlW7xKL.css,01XPHJk60-L.css,014OeDQisGL.css,21aPhFy+riL.css,11gneA3MtJL.css,21fecG8pUzL.css,01RddH8vm-L.css,01CFUgsA
# ...

# %%
soup7a = BeautifulSoup(page7a.content)

# %%
Names = []
Price = []
Image = []
Rating = []

data = {'Names':Names,'Price':Price,'Image':Image,'Rating':Rating}

data1 = pd.DataFrame(data)

# %%
#for i in range(len(tag)):
data2 = get_info(soup7a,tag[0],classes[0])
read_text(Names,data2)
# Out:
# ['Oppo A31 (Fantasy White, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#  'Samsung Galaxy M02s (Blue,4GB RAM, 64GB Storage) | 5000 mAh | Triple Camera',
#  'Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Storage)',
#  'Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64GB Storage)',
#  'Redmi 8A Dual (Sea Blue, 3GB RAM, 64GB Storage) – Dual Cameras & 5,000 mAH Battery',
#  'Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor',
#  'Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage) | 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor',
#  'Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage) | 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor',
#  'Redmi 9A (Nature Green, 2GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor',
#  'Redmi 9A (Nature Green, 3GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor',
#  'Vivo Y91i (Fusion Black, 2GB RAM, 32GB Storage) with No Cost EMI/Additional Exchange Offers',
# ...

# %%
data2 = get_info(soup7a,tag[1],classes[1])
read_text(Price,data2)
# Out:
# ['10,990',
#  '9,999',
#  '12,499',
#  '12,499',
#  '9,298',
#  '8,499',
#  '8,499',
#  '8,499',
#  '6,799',
#  '7,499',
#  '7,490',
#  '7,490',
#  '14,499',
#  '10,990',
#  '9,990',
#  '9,999',
#  '9,999',
#  '9,999',
#  '9,999',
#  '9,999',
#  '9,999',
#  '7,499',
#  '7,990',
#  '7,499']

# %%
def read_image(var,ol):
    num = 1
    for i in ol:
        if num <= len(ol):
            var.append(i.get('src'))
            num+=1
        else:
            break
    return var

# %% [markdown]
# Tried the above code for getting images link.
#
# .get('src') , found this command from searching in internet.

# %%
data2 = get_info(soup7a,tag[2],classes[2])
read_image(Image,data2)
# Out:
# ['https://m.media-amazon.com/images/I/61IhTtJUXJL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71wkpcIfqdL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71OGzLCrjZS._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71dujTTJDZL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71yXShgxvpL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/716nHhG9SWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71A9Vo1BatL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71sxlhYhKWL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51ZoulFBPGL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/51FnmxwFHDL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71Kmfs0T0BL._AC_UL320_.jpg',
#  'https://m.media-amazon.com/images/I/71KCwNV6MuL._AC_UL320_.jpg',
# ...

# %%
data2 = get_info(soup7a,tag[3],classes[3])
read_text(Rating,data2)
# Out:
# ['4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4 Stars & Up',
#  '3 Stars & Up',
#  '2 Stars & Up',
#  '1 Star & Up']

# %%
data
# Out:
# {'Names': ['Oppo A31 (Fantasy White, 6GB RAM, 128GB Storage) with No Cost EMI/Additional Exchange Offers',
#   'Samsung Galaxy M02s (Blue,4GB RAM, 64GB Storage) | 5000 mAh | Triple Camera',
#   'Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Storage)',
#   'Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64GB Storage)',
#   'Redmi 8A Dual (Sea Blue, 3GB RAM, 64GB Storage) – Dual Cameras & 5,000 mAH Battery',
#   'Redmi 9 (Sky Blue, 4GB RAM, 64GB Storage)| 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor',
#   'Redmi 9 (Carbon Black, 4GB RAM, 64GB Storage) | 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor',
#   'Redmi 9 (Sporty Orange, 4GB RAM, 64GB Storage) | 5000 mAh| 2.3GHz Mediatek Helio G35 Octa core Processor',
#   'Redmi 9A (Nature Green, 2GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor',
#   'Redmi 9A (Nature Green, 3GB Ram, 32GB Storage) | 2GHz Octa-core Helio G25 Processor',
# ...

# %% [markdown]
# Ratings got 4 unnecessary values added in the list at the end

# %%
del(data['Rating'][-4:])

# %%
data['Rating']
# Out:
# ['4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.0 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.1 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars',
#  '4.2 out of 5 stars']

# %%
data1 = pd.DataFrame(data)

# %%
data1.shape
# Out:
# (24, 4)

# %%
data1.head()
# Out:
#                                                Names   Price  \
# 0  Oppo A31 (Fantasy White, 6GB RAM, 128GB Storag...  10,990
# 1  Samsung Galaxy M02s (Blue,4GB RAM, 64GB Storag...   9,999
# 2  Redmi Note 10 (Aqua Green, 4GB RAM, 64GB Storage)  12,499
# 3  Samsung Galaxy M21 (Midnight Blue, 4GB RAM, 64...  12,499
# 4  Redmi 8A Dual (Sea Blue, 3GB RAM, 64GB Storage...   9,298
#
#                                                Image              Rating
# 0  https://m.media-amazon.com/images/I/61IhTtJUXJ...  4.2 out of 5 stars
# 1  https://m.media-amazon.com/images/I/71wkpcIfqd...  4.1 out of 5 stars
# 2  https://m.media-amazon.com/images/I/71OGzLCrjZ...  4.1 out of 5 stars
# 3  https://m.media-amazon.com/images/I/71dujTTJDZ...  4.2 out of 5 stars
# 4  https://m.media-amazon.com/images/I/71yXShgxvp...  4.1 out of 5 stars

# %% [markdown]
# 7 is done

# %% [markdown]
# 8) Write a python program to extract information about the local weather from the National Weather Service website of USA, https://www.weather.gov/ for the city, San Francisco.
#
#     You need to extract data about 7 day extended forecast display for the city.
#
#     The data should include period, short description, temperature and description

# %%
page8 = requests.get('https://forecast.weather.gov/MapClick.php?lat=37.7771&lon=-122.4196#.YJTTUrUzZPb')
page8
# Out:
# <Response [200]>

# %%
soup8 = BeautifulSoup(page8.content)

# %%
times = soup8.find_all('div',class_='col-sm-2 forecast-label')

# %%
Label = []
for i in times:
    Label.append(i.text)

# %%
Label
# Out:
# ['Tonight',
#  'Friday',
#  'Friday Night',
#  'Saturday',
#  'Saturday Night',
#  'Sunday',
#  'Sunday Night',
#  'Monday',
#  'Monday Night',
#  'Tuesday',
#  'Tuesday Night',
#  'Wednesday',
#  'Wednesday Night',
#  'Thursday']

# %%
sd = soup8.find_all('p',class_='short-desc')

# %%
Short_desc = []
for i in sd:
    Short_desc.append(i.text)

# %%
Short_desc
# Out:
# ['Mostly Clear',
#  'Sunny',
#  'Clear',
#  'Sunny',
#  'Mostly Clear',
#  'Sunny',
#  'Clear',
#  'Sunny',
#  'Clear']

# %%
lowtemps = soup8.find_all('p',class_='temp temp-low')
hightemps = soup8.find_all('p',class_='temp temp-high')

# %%
Temp = []

low = 0
high = 0

for i in range(len(lowtemps)+len(hightemps)):
    
    if i%2 == 0:
        Temp.append(lowtemps[low].text)
        low+=1
    else:
        Temp.append(hightemps[high].text)
        high+=1

# %%
Temp
# Out:
# ['Low: 50 °F',
#  'High: 66 °F',
#  'Low: 50 °F',
#  'High: 72 °F',
#  'Low: 53 °F',
#  'High: 70 °F',
#  'Low: 52 °F',
#  'High: 72 °F',
#  'Low: 52 °F']

# %%
desc = soup8.find_all('div',class_='col-sm-10 forecast-text')

# %%
Description = []
for i in desc:
    Description.append(i.text)

# %%
Description
# Out:
# ['Mostly clear, with a low around 50. West wind 9 to 14 mph, with gusts as high as 22 mph. ',
#  'Sunny, with a high near 66. Light south southwest wind becoming west 9 to 14 mph in the afternoon. Winds could gust as high as 20 mph. ',
#  'Clear, with a low around 50. West wind 5 to 11 mph. ',
#  'Sunny, with a high near 72. Northwest wind 8 to 13 mph, with gusts as high as 25 mph. ',
#  'Mostly clear, with a low around 53. West wind 7 to 13 mph. ',
#  'Sunny, with a high near 70.',
#  'Clear, with a low around 52.',
#  'Sunny, with a high near 72.',
#  'Clear, with a low around 52.',
#  'Sunny, with a high near 72.',
#  'Mostly clear, with a low around 51.',
#  'Sunny, with a high near 68.',
#  'Mostly clear, with a low around 51.',
#  'Sunny, with a high near 66.']

# %%
print(len(Label),len(Short_desc),len(Temp),len(Description))
# Out:
# 14 9 9 14

# %% [markdown]
# short desc and temp has less values than other columns. Therefore filling the missing with nan values to make a dataframe

# %%
import numpy as np
for i in range(5):
    Short_desc.append(np.nan)
    Temp.append(np.nan)

# %%
print(len(Label),len(Short_desc),len(Temp),len(Description))
# Out:
# 14 14 14 14

# %%
Forecast = {'Period':Label,'Short-desc':Short_desc,'Temperature':Temp,'Description':Description}

# %%
Forecast_SF = pd.DataFrame(Forecast)
Forecast_SF.sample(5)
# Out:
#            Period    Short-desc  Temperature  \
# 13       Thursday           NaN          NaN
# 3        Saturday         Sunny  High: 72 °F
# 6    Sunday Night         Clear   Low: 52 °F
# 0         Tonight  Mostly Clear   Low: 50 °F
# 10  Tuesday Night           NaN          NaN
#
#                                           Description
# 13                        Sunny, with a high near 66.
# 3   Sunny, with a high near 72. Northwest wind 8 t...
# 6                        Clear, with a low around 52.
# 0   Mostly clear, with a low around 50. West wind ...
# 10                Mostly clear, with a low around 51.
